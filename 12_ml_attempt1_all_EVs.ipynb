# %%
ean_numbers = ['541480930594258894', '541261957970628703', '541560923639711466']  # '541983310278725782', '541792416037150809', 

ean_number = ean_numbers[1]

# %%
for ean_number in ean_numbers:
    import pandas as pd


    # read data from csv
    df = pd.read_csv(f'data_assets_reformatted/all_data_{ean_number}.csv')

    # rename columns: timestamp, connected to Date, Value
    df.rename(columns={'timestamp': 'Date', 'connected': 'Value'}, inplace=True)

    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)


    df['Value'] = df['Value'].astype(int)


    train_size = int(len(df) * 0.7)
    val_size = int(len(df) * 0.2)
    test_size = len(df) - train_size - val_size

    train, val, test = df.iloc[0:train_size], df.iloc[train_size:train_size+val_size], df.iloc[train_size+val_size:len(df)]


    from sklearn.preprocessing import MinMaxScaler

    scaler = MinMaxScaler(feature_range=(0, 1))
    train_scaled = scaler.fit_transform(train)
    val_scaled = scaler.transform(val)
    test_scaled = scaler.transform(test)



    import numpy as np

    def create_dataset(X, y, time_steps=1):
        Xs, ys = [], []
        for i in range(len(X) - time_steps):
            v = X.iloc[i:(i + time_steps)].values
            Xs.append(v)
            ys.append(y.iloc[i + time_steps])
        return np.array(Xs), np.array(ys)

    time_steps = 10

    X_train, y_train = create_dataset(train, train.Value, time_steps)
    X_val, y_val = create_dataset(val, val.Value, time_steps)
    X_test, y_test = create_dataset(test, test.Value, time_steps)



    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import LSTM, Dense

    model = Sequential()
    model.add(LSTM(128, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    history = model.fit(
        X_train, y_train,
        epochs=30,
        batch_size=32,
        validation_data=(X_val, y_val),
        shuffle=False
    )


    y_pred = model.predict(X_test)


    loss, accuracy = model.evaluate(X_test, y_test)
    print('Test loss:', loss)
    print('Test accuracy:', accuracy)


    import matplotlib.pyplot as plt

    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()


    from sklearn.metrics import classification_report, roc_auc_score

    y_pred = model.predict(X_test)

    # print(classification_report(y_test, y_pred))

    # roc_auc = roc_auc_score(y_test, y_pred)
    # print('AUC-ROC:', roc_auc)


    # plot y_test and y_pred
    plt.figure(figsize=(12, 3))
    plt.plot(y_test, label='True')
    plt.plot(y_pred, label='Predicted')
    plt.legend()
    plt.show()




    # save the model
    model.save(f'models/model_{ean_number}.keras')
# Out:
# Epoch 1/30
# /Users/niaki/Workspace/personal/Elia-Hackathon-Steering/.venv/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9272 - loss: 0.2538 - val_accuracy: 0.9793 - val_loss: 0.0800
# Epoch 2/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9817 - loss: 0.0800 - val_accuracy: 0.9863 - val_loss: 0.0685
# Epoch 3/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9865 - loss: 0.0699 - val_accuracy: 0.9863 - val_loss: 0.0675
# Epoch 4/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9865 - loss: 0.0687 - val_accuracy: 0.9863 - val_loss: 0.0673
# Epoch 5/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.
30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9860 - loss: 0.0710 - val_accuracy: 0.9851 - val_loss: 0.0720
# Epoch 5/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9860 - loss: 0.0704 - val_accuracy: 0.9851 - val_loss: 0.0722
# Epoch 6/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9860 - loss: 0.0700 - val_accuracy: 0.9851 - val_loss: 0.0725
# Epoch 7/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9860 - loss: 0.0697 - val_accuracy: 0.9850 - val_loss: 0.0725
# Epoch 8/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9860 - loss: 0.0694 - val_accuracy: 0.9850 - val_loss: 0.0727
# Epoch 9/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9860 - loss: 0.0692 - val_accuracy: 0.9849 - val_loss: 0.0730
# Epoch 10/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9860 - loss: 0.0689 - val_accuracy: 0.9849 - val_loss: 0.0734
# Epoch 11/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9860 - loss: 0.0686 - val_accuracy: 0.9847 - val_loss: 0.0740
# Epoch 12/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9860 - loss: 0.0685 - val_accuracy: 0.9850 - val_loss: 0.0730
# Epoch 13/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9860 - loss: 0.0685 - val_accuracy: 0.9847 - val_loss: 0.0736
# Epoch 14/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9860 - loss: 0.0682 - val_accuracy: 0.9847 - val_loss: 0.0736
# Epoch 15/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9860 - loss: 0.0680 - val_accuracy: 0.9847 - val_loss: 0.0738
# Epoch 16/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9860 - loss: 0.0680 - val_accuracy: 0.9846 - val_loss: 0.0739
# Epoch 17/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9860 - loss: 0.0679 - val_accuracy: 0.9846 - val_loss: 0.0741
# Epoch 18/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9860 - loss: 0.0679 - val_accuracy: 0.9847 - val_loss: 0.0741
# Epoch 19/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9860 - loss: 0.0679 - val_accuracy: 0.9847 - val_loss: 0.0741
# Epoch 20/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9860 - loss: 0.0678 - val_accuracy: 0.9847 - val_loss: 0.0745
# Epoch 21/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9860 - loss: 0.0680 - val_accuracy: 0.9847 - val_loss: 0.0740
# Epoch 22/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9860 - loss: 0.0678 - val_accuracy: 0.9847 - val_loss: 0.0748
# Epoch 23/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9860 - loss: 0.0678 - val_accuracy: 0.9847 - val_loss: 0.0750
# Epoch 24/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9860 - loss: 0.0677 - val_accuracy: 0.9847 - val_loss: 0.0750
# Epoch 25/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9860 - loss: 0.0677 - val_accuracy: 0.9847 - val_loss: 0.0750
# Epoch 26/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9860 - loss: 0.0677 - val_accuracy: 0.9847 - val_loss: 0.0750
# Epoch 27/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9860 - loss: 0.0677 - val_accuracy: 0.9847 - val_loss: 0.0753
# Epoch 28/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9860 - loss: 0.0677 - val_accuracy: 0.9847 - val_loss: 0.0751
# Epoch 29/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9860 - loss: 0.0677 - val_accuracy: 0.9847 - val_loss: 0.0744
# Epoch 30/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9860 - loss: 0.0677 - val_accuracy: 0.9847 - val_loss: 0.0752
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9881 - loss: 0.0589
# Test loss: 0.0636720359325409
# Test accuracy: 0.9868143200874329
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/30
# /Users/niaki/Workspace/personal/Elia-Hackathon-Steering/.venv/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9283 - loss: 0.2564 - val_accuracy: 0.9729 - val_loss: 0.0852
# Epoch 2/30
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.